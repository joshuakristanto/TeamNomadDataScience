# %% [markdown]
# # Titanic Kaggle Project 2
# * Albert Eng
# * Jose De La Rosa
# * Joshua Kristanto

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %% [markdown]
# # Reading the Data Set twice

# %%
data = pd.read_csv("train.csv")
data2 = pd.read_csv("train.csv")

# %%
data2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %% [markdown]
# # Dropped Names, Cabin, Embarked, Ticket, PassengerId, PClass, Parch

# %%
data = data.drop(columns = "Name")
data = data.drop(columns = "Cabin")
data = data.drop(columns = "Embarked")
data = data.drop(columns = "Ticket")
data = data.drop(columns = "PassengerId")
data = data.drop(columns = "Pclass")
data = data.drop(columns= "Parch")
#data = data.drop(columns= "SibSp")
#data = data.drop(columns = "Fare")
data
# Out:
#      Survived     Sex   Age  SibSp      Fare
# 0           0    male  22.0      1    7.2500
# 1           1  female  38.0      1   71.2833
# 2           1  female  26.0      0    7.9250
# 3           1  female  35.0      1   53.1000
# 4           0    male  35.0      0    8.0500
# 5           0    male   NaN      0    8.4583
# 6           0    male  54.0      0   51.8625
# 7           0    male   2.0      3   21.0750
# 8           1  female  27.0      0   11.1333
# 9           1  female  14.0      1   30.0708
# 10          1  female   4.0      1   16.7000
# 11          1  female  58.0      0   26.5500
# 12          0    male  20.0      0    8.0500
# 13          0    male  39.0      1   31.2750
# 14          0  female  14.0      0    7.8542
# 15          1  female  55.0      0   16.0000
# 16          0    male   2.0      4   29.1250
# 17          1    male   NaN      0   13.0000
# 18          0  female  31.0      1   18.0000
# 19          1  female   NaN      0    7.2250
# ...

# %% [markdown]
# * Converted Sex to dummies, and filled Age and Fare NA's with Dummies

# %%
data
data = pd.get_dummies(data, columns=['Sex'], prefix = ['Sex'])
#data = pd.get_dummies(data, columns=['Pclass'], prefix = ['pClass'])
data['Age'].fillna(data['Age'].mean(), inplace=True)
data['Fare'].fillna(data['Fare'].mean(), inplace=True)

# %%
list(data) # Listing the current available attributes from data
# Out:
# ['Survived', 'Age', 'SibSp', 'Fare', 'Sex_female', 'Sex_male']

# %% [markdown]
# ## Heatmap of correlations between the reduced dataset and survivors

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

X = data.iloc[:,1:78]  #independent columns
y = data2.iloc[:,-1]    #target column i.e price range
#print(y)

#get correlations of each features in dataset
corrmat = data.corr()
top_corr_features = corrmat.index

#print(corrmat)
plt.figure(figsize=(20,20))

#plot heat map
g=sns.heatmap(data[top_corr_features].corr(),annot=True,cmap="RdYlGn")
data = data.drop(columns ="Sex_male")

# %% [markdown]
# ## Save Survived to y

# %%
y = np.array(data["Survived"])
data
# Out:
#      Survived        Age  SibSp      Fare  Sex_female
# 0           0  22.000000      1    7.2500           0
# 1           1  38.000000      1   71.2833           1
# 2           1  26.000000      0    7.9250           1
# 3           1  35.000000      1   53.1000           1
# 4           0  35.000000      0    8.0500           0
# 5           0  29.699118      0    8.4583           0
# 6           0  54.000000      0   51.8625           0
# 7           0   2.000000      3   21.0750           0
# 8           1  27.000000      0   11.1333           1
# 9           1  14.000000      1   30.0708           1
# 10          1   4.000000      1   16.7000           1
# 11          1  58.000000      0   26.5500           1
# 12          0  20.000000      0    8.0500           0
# 13          0  39.000000      1   31.2750           0
# 14          0  14.000000      0    7.8542           1
# 15          1  55.000000      0   16.0000           1
# ...

# %% [markdown]
# ## Dropped Survived from main Dataset

# %%
data = data.drop(columns = "Survived")

# %% [markdown]
# ## Saved the Rest of the attributes into x

# %%
x = np.array(data)
x
# Out:
# array([[22.        ,  1.        ,  7.25      ,  0.        ],
#        [38.        ,  1.        , 71.2833    ,  1.        ],
#        [26.        ,  0.        ,  7.925     ,  1.        ],
#        ...,
#        [29.69911765,  1.        , 23.45      ,  1.        ],
#        [26.        ,  0.        , 30.        ,  0.        ],
#        [32.        ,  0.        ,  7.75      ,  0.        ]])

# %% [markdown]
# # BayesTheorem

# %% [markdown]
# ## One iteration of Bayes

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
gnb=GaussianNB()
XTRAIN, XTEST, YTRAIN, YTEST=train_test_split(x,y)
gnb.fit(XTRAIN,YTRAIN)
YP=gnb.predict(XTEST)

# %%
print(confusion_matrix(YTEST,YP))
err = 1-accuracy_score(YTEST,YP)
print("error = %7.6f" %err)
# Out:
# [[124  18]
#  [ 24  57]]
# error = 0.188341

# %% [markdown]
# ## 100 Splits on Bayes

# %%
errs=[]
nsplits = 100
for split in range(nsplits):
    XTRAIN, XTEST, YTRAIN, YTEST=train_test_split(x,y,test_size=.25)
    gnb.fit(XTRAIN,YTRAIN)
    YP=gnb.predict(XTEST)
    errs.append(1-accuracy_score(YTEST,YP))
print("%d Splits: Mean Error=%7.6f +/- %7.6f (95%%)"\
      %(nsplits, np.mean(errs),1.96*np.std(errs)))
print(confusion_matrix(YTEST,YP))
# Out:
# 100 Splits: Mean Error=0.206906 +/- 0.044627 (95%)
# [[112  19]
#  [ 28  64]]

# %%
np.mean(errs)-1.96*np.std(errs), np.mean(errs)+1.96*np.std(errs)
# Out:
# (0.1622790000538671, 0.25153265913895795)

# %% [markdown]
# # TEST
# * Reading and running the predicted formula from train to actually predict from train.

# %%
from scipy.stats import kurtosis
kurtosis(x, fisher=False)
# Out:
# array([ 3.95413892, 20.77351175, 36.20428925,  1.38177373])

# %%
test = pd.read_csv("test.csv")
test2 = pd.read_csv("test.csv")
test = test.drop(columns = "Name")
test = test.drop(columns = "Cabin")
test = test.drop(columns = "Embarked")
test = test.drop(columns = "Ticket")
test = test.drop(columns = "PassengerId")
test = test.drop(columns = "Pclass")
test = test.drop(columns= "Parch")
#test = test.drop(columns= "SibSp")
#test = test.drop(columns= "Fare")
test = pd.get_dummies(test, columns=['Sex'], prefix = ['Sex'])
#test = pd.get_dummies(test, columns=['Pclass'], prefix = ['pClass'])
test['Age'].fillna(test['Age'].mean(), inplace=True)
test['Fare'].fillna(data['Fare'].mean(), inplace=True)
test = test.drop(columns ="Sex_male")
YP=gnb.predict(test)

# %%
test2["PassengerId"]
# Out:
# 0       892
# 1       893
# 2       894
# 3       895
# 4       896
# 5       897
# 6       898
# 7       899
# 8       900
# 9       901
# 10      902
# 11      903
# 12      904
# 13      905
# 14      906
# 15      907
# 16      908
# 17      909
# 18      910
# 19      911
# 20      912
# 21      913
# 22      914
# 23      915
# 24      916
# 25      917
# 26      918
# 27      919
# 28      920
# 29      921
#        ...
# 388    1280
# 389    1281
# 390    1282
# 391    1283
# 392    1284
# 393    1285
# 394    1286
# 395    1287
# 396    1288
# 397    1289
# 398    1290
# 399    1291
# 400    1292
# 401    1293
# 402    1294
# 403    1295
# 404    1296
# 405    1297
# 406    1298
# 407    1299
# 408    1300
# 409    1301
# 410    1302
# 411    1303
# 412    1304
# 413    1305
# 414    1306
# 415    1307
# 416    1308
# 417    1309
# Name: PassengerId, Length: 418, dtype: int64

# %% [markdown]
# # Creates an uploadable file to Kaggle

# %%
df = pd.DataFrame({"PassengerId":np.array(test2["PassengerId"]),
                  "Survived": YP})
df.to_csv("result.csv", sep =",",index = False)

# %%
def visualize_clasifier_contours(clf,X,Y,DX,DY,thelevels,colors,markers,xlab="X",
                                ylab="Y", filename='classifier-figure.pdf'):
    xinterval = X[:, 0].min() - 1, X[:, 0].max() + 1
    yinterval = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(*xinterval, DX),
                         np.arange(*yinterval, DY))
    
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    
    c=plt.contour(xx, yy, Z, alpha=1,levels=thelevels,linewidths=2,colors="k")
    c=plt.contourf(xx, yy, Z, alpha=.1)

  
    nclasses=len(colors)
    for i in range(nclasses):
        x,y=zip(*X[Y==i])
        plt.scatter(x,y,marker=markers[i],color=colors[i],s=100)


    plt.xlabel(xlab,fontsize=14)
    plt.ylabel(ylab,fontsize=14)
    plt.grid()
    fig=plt.gcf()
    fig.tight_layout()
    fig.set_size_inches(6,6)
    fig.savefig(filename)

# %%
data
# Out:
#            Age  SibSp      Fare  Sex_female
# 0    22.000000      1    7.2500           0
# 1    38.000000      1   71.2833           1
# 2    26.000000      0    7.9250           1
# 3    35.000000      1   53.1000           1
# 4    35.000000      0    8.0500           0
# 5    29.699118      0    8.4583           0
# 6    54.000000      0   51.8625           0
# 7     2.000000      3   21.0750           0
# 8    27.000000      0   11.1333           1
# 9    14.000000      1   30.0708           1
# 10    4.000000      1   16.7000           1
# 11   58.000000      0   26.5500           1
# 12   20.000000      0    8.0500           0
# 13   39.000000      1   31.2750           0
# 14   14.000000      0    7.8542           1
# 15   55.000000      0   16.0000           1
# 16    2.000000      4   29.1250           0
# 17   29.699118      0   13.0000           0
# 18   31.000000      1   18.0000           1
# 19   29.699118      0    7.2250           1
# ...

# %%
aaa = np.array(data["Fare"])

# %%
file_n = 
bbb = np.array(data["Survived"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Survived'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-9b2c836c4475> in <module>
# ----> 1 bbb = np.array(data["Survived"])
#
# ...

# %%
colors=["red", "green","blue","purple"]
markers=["$4$","$6$","$8$","$10$"]
visualize_clasifier_contours(gnb,aaa,bbb,.1,.1, [0.5,1.5],colors,markers,"MPG","Acceleration")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-e2bab701f9f8> in <module>
#       1 colors=["red", "green","blue","purple"]
#       2 markers=["$4$","$6$","$8$","$10$"]
# ----> 3 visualize_clasifier_contours(gnb,aaa,bbb,.1,.1, [0.5,1.5],colors,markers,"MPG","Acceleration")
#
# NameError: name 'bbb' is not defined
